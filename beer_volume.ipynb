# %%
import pandas as pd
import numpy as np

NUM_OF_ITERATIONS = 50

# читаем размеченные данные из файла
beer_dataset = pd.read_excel('beer_data_set.xlsx')

data = [item for item in beer_dataset[['SKU_NAME']].values.flatten()]
volumes = beer_dataset['Объем'].values.flatten()

# выводим несколько первых строк таблицы
beer_dataset.head()
# Out:
#          barcode                                  SKU_NAME  \
# 0  4600721002206                  Пиво БагБир 0.5л  ст/бут
# 1  4600721003197                 Пиво БАГ-БИР св.ст/б 0.5л
# 2  4600721003203          Пиво BAGBIER светлое 4,9%   1.5л
# 3  4600721005191                  Пиво БАГ-БИР св.ПЭТ 2.5л
# 4  4600721009366  Пиво БАГ БИР ГОЛЬДЕН светлое ПЭТ 4% 1,5л
#
#                                  Наименование  Алкоголь  Объем Производитель  \
# 0      BAGBIER - светлое - 4.2% - 0.5л стекло     0.042    0.5      AB InBev
# 1      BAGBIER - светлое - 4.2% - 0.5л стекло     0.042    0.5      AB InBev
# 2         BAGBIER - светлое - 4.9% - 1.5л пэт     0.049    1.5      AB InBev
# 3         BAGBIER - светлое - 4.2% - 2.5л пэт     0.042    2.5      AB InBev
# 4  BAGBIER GOLDEN - светлое - 4.7% - 1.5л пэт     0.047    1.5      AB InBev
#
#      Бренд Саб-бренд Тип упаковки  Мультипак      тип
# 0  BAGBIER       NaN       Стекло        NaN  Светлое
# 1  BAGBIER       NaN       Стекло        NaN  Светлое
# 2  BAGBIER       NaN          ПЭТ        NaN  Светлое
# 3  BAGBIER       NaN          ПЭТ        NaN  Светлое
# 4  BAGBIER    Golden          ПЭТ        NaN  Светлое

# %%
import re 
import random
import time

random.seed(time.time())
analyzer = 'word'
#token_pattern = r"(?u)\b\w\w+\b|[0-9]+[0-9\.,]+\w+"
token_pattern = r"(?u)[0-9]+[0-9\.,]+\w+|[0-9]+\w"

def tokenize(items, token_pattern):
    pat = re.compile(token_pattern)
    tokens = []
    for item in items:
        tokens.append([match.group() for match in re.finditer(pat, item)])
    data = zip(items, tokens)
    return pd.DataFrame(data, columns=['Строка', 'Токены'])

tokenize(random.sample(data, 10), token_pattern)
# Out:
#                                     Строка        Токены
# 0            Пиво ЛЕДОКОЛ свет.8% ж/б 0.5л        [0.5л]
# 1        Пиво ДОН ЖИВОЕ св.непаст.4% 0.47л       [0.47л]
# 2       KOFF - светлое 4.5% - 0.44л стекло  [4.5, 0.44л]
# 3         БАЛТИКА - светлое 0% - 0.5л ж.б.        [0.5л]
# 4              ZHIGULYOVSKOE 2 1L P BO L X          [1L]
# 5          Пиво CORONA EXTRA MEX.бут 0.33л       [0.33л]
# 6  ZHIGULYOVSK.(BRYANSKPIVO) 0.5L J BO L X        [0.5L]
# 7   ХАМОВНИКИ - светлое 4.5% - 0.5л стекло   [4.5, 0.5л]
# 8         FAXE - светлое 4.9% - 0.48л ж.б.  [4.9, 0.48л]
# 9     Пиво ЗОЛ.БОЧКА ПШЕНИЧ.5,3% ст/б 0.5л   [5,3, 0.5л]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor, CatBoostClassifier
from joblib import load

def dense_vectors(vectors):
    return np.array([np.asarray(item.todense())[0] for item in vectors])

train_data, test_data, train_volumes, test_volumes = train_test_split(data, volumes, test_size=0.33, random_state=42)

def enrich(vectors, data):
    container_predictor = CatBoostClassifier()
    container_predictor.load_model('beer_container_catboost_400.cbm')
    vect = load('beer_container_catboost_400_vect.job')
    data = dense_vectors(vect.transform(data))
    padding = container_predictor.predict(data)
    enriched = np.concatenate((vectors, padding), axis=1)
    return enriched

def build_model(data, volumes, iterations=200):
        vectorizer = CountVectorizer(lowercase=True, token_pattern=token_pattern)
        
        compressed_data = vectorizer.fit_transform(data)
        vectorized_data = dense_vectors(compressed_data)
        enriched_data = enrich(vectorized_data, data)
        print(enriched_data.shape)
        reg = CatBoostClassifier(iterations=iterations)
        reg.fit(enriched_data, volumes, silent=False)
        
        return (vectorizer, reg)

# %%
model = build_model(train_data, train_volumes, iterations=300)
# Out:
# (3902, 217)
# 0:	learn: -3.2117047	total: 182ms	remaining: 54.5s
# 1:	learn: -2.8973649	total: 356ms	remaining: 53s
# 2:	learn: -2.6859763	total: 549ms	remaining: 54.4s
# 3:	learn: -2.5072487	total: 719ms	remaining: 53.2s
# 4:	learn: -2.3665727	total: 845ms	remaining: 49.9s
# 5:	learn: -2.2590021	total: 900ms	remaining: 44.1s
# 6:	learn: -2.1524072	total: 957ms	remaining: 40s
# 7:	learn: -2.0615065	total: 1.01s	remaining: 37s
# 8:	learn: -1.9873080	total: 1.07s	remaining: 34.8s
# 9:	learn: -1.9152530	total: 1.13s	remaining: 32.8s
# 10:	learn: -1.8468918	total: 1.18s	remaining: 31s
# 11:	learn: -1.7820973	total: 1.24s	remaining: 29.7s
# 12:	learn: -1.7310553	total: 1.3s	remaining: 28.6s
# 13:	learn: -1.6763270	total: 1.35s	remaining: 27.6s
# 14:	learn: -1.6245082	total: 1.41s	remaining: 26.7s
# 15:	learn: -1.5784614	total: 1.47s	remaining: 26.2s
# 16:	learn: -1.5388579	total: 1.54s	remaining: 25.6s
# 17:	learn: -1.5047806	total: 1.59s	remaining: 24.9s
# 18:	learn: -1.4694432	total: 1.65s	remaining: 24.3s
# 19:	learn: -1.4332924	total: 1.7s	remaining: 23.9s
# 20:	learn: -1.4021361	total: 1.76s	remaining: 23.4s
# 21:	learn: -1.3713178	total: 1.83s	remaining: 23.1s
# 22:	learn: -1.3445018	total: 2.05s	remaining: 24.7s
# 23:	learn: -1.3111613	total: 2.21s	remaining: 25.4s
# 24:	learn: -1.2803173	total: 2.4s	remaining: 26.4s
# 25:	learn: -1.2510906	total: 2.57s	remaining: 27.1s
# 26:	learn: -1.2231147	total: 2.75s	remaining: 27.8s
# 27:	learn: -1.1964097	total: 2.84s	remaining: 27.6s
# 28:	learn: -1.1718662	total: 2.9s	remaining: 27.1s
# 29:	learn: -1.1524586	total: 2.96s	remaining: 26.6s
# 30:	learn: -1.1333001	total: 3.02s	remaining: 26.2s
# 31:	learn: -1.1142834	total: 3.08s	remaining: 25.8s
# 32:	learn: -1.0963981	total: 3.13s	remaining: 25.3s
# 33:	learn: -1.0764552	total: 3.19s	remaining: 25s
# 34:	learn: -1.0594215	total: 3.25s	remaining: 24.6s
# 35:	learn: -1.0413948	total: 3.3s	remaining: 24.2s
# 36:	learn: -1.0247593	total: 3.36s	remaining: 23.9s
# 37:	learn: -1.0083275	total: 3.42s	remaining: 23.6s
# 38:	learn: -0.9912812	total: 3.48s	remaining: 23.3s
# 39:	learn: -0.9727201	total: 3.53s	remaining: 23s
# 40:	learn: -0.9572402	total: 3.59s	remaining: 22.7s
# 41:	learn: -0.9408905	total: 3.66s	remaining: 22.5s
# 42:	learn: -0.9270225	total: 3.71s	remaining: 22.2s
# 43:	learn: -0.9136072	total: 3.77s	remaining: 21.9s
# 44:	learn: -0.8983663	total: 3.88s	remaining: 22s
# 45:	learn: -0.8847867	total: 4.07s	remaining: 22.5s
# 46:	learn: -0.8730747	total: 4.26s	remaining: 22.9s
# 47:	learn: -0.8610795	total: 4.44s	remaining: 23.3s
# 48:	learn: -0.8485889	total: 4.64s	remaining: 23.8s
# 49:	learn: -0.8361550	total: 4.79s	remaining: 24s
# 50:	learn: -0.8248649	total: 4.86s	remaining: 23.7s
# 51:	learn: -0.8147869	total: 4.91s	remaining: 23.4s
# 52:	learn: -0.8014205	total: 4.99s	remaining: 23.2s
# 53:	learn: -0.7907579	total: 5.04s	remaining: 23s
# 54:	learn: -0.7795950	total: 5.11s	remaining: 22.8s
# 55:	learn: -0.7710886	total: 5.16s	remaining: 22.5s
# 56:	learn: -0.7615963	total: 5.22s	remaining: 22.3s
# 57:	learn: -0.7509448	total: 5.27s	remaining: 22s
# 58:	learn: -0.7411387	total: 5.33s	remaining: 21.8s
# 59:	learn: -0.7321486	total: 5.39s	remaining: 21.6s
# 60:	learn: -0.7232725	total: 5.44s	remaining: 21.3s
# 61:	learn: -0.7144255	total: 5.5s	remaining: 21.1s
# 62:	learn: -0.7045672	total: 5.57s	remaining: 21s
# 63:	learn: -0.6958083	total: 5.65s	remaining: 20.8s
# 64:	learn: -0.6880986	total: 5.72s	remaining: 20.7s
# 65:	learn: -0.6806281	total: 5.8s	remaining: 20.6s
# 66:	learn: -0.6739896	total: 5.98s	remaining: 20.8s
# 67:	learn: -0.6673225	total: 6.17s	remaining: 21.1s
# 68:	learn: -0.6609923	total: 6.33s	remaining: 21.2s
# 69:	learn: -0.6536707	total: 6.52s	remaining: 21.4s
# 70:	learn: -0.6472009	total: 6.72s	remaining: 21.7s
# 71:	learn: -0.6389637	total: 6.82s	remaining: 21.6s
# 72:	learn: -0.6319771	total: 6.89s	remaining: 21.4s
# 73:	learn: -0.6266597	total: 6.96s	remaining: 21.3s
# 74:	learn: -0.6208667	total: 7.01s	remaining: 21s
# 75:	learn: -0.6140195	total: 7.07s	remaining: 20.8s
# 76:	learn: -0.6085233	total: 7.12s	remaining: 20.6s
# 77:	learn: -0.6035226	total: 7.18s	remaining: 20.4s
# 78:	learn: -0.5976395	total: 7.24s	remaining: 20.2s
# 79:	learn: -0.5928782	total: 7.3s	remaining: 20.1s
# 80:	learn: -0.5878091	total: 7.37s	remaining: 19.9s
# 81:	learn: -0.5821170	total: 7.45s	remaining: 19.8s
# 82:	learn: -0.5773599	total: 7.53s	remaining: 19.7s
# 83:	learn: -0.5723650	total: 7.61s	remaining: 19.6s
# 84:	learn: -0.5678866	total: 7.69s	remaining: 19.5s
# 85:	learn: -0.5633096	total: 7.95s	remaining: 19.8s
# 86:	learn: -0.5602657	total: 8.18s	remaining: 20s
# 87:	learn: -0.5557636	total: 8.38s	remaining: 20.2s
# 88:	learn: -0.5515330	total: 8.66s	remaining: 20.5s
# 89:	learn: -0.5463779	total: 8.77s	remaining: 20.5s
# 90:	learn: -0.5421292	total: 8.84s	remaining: 20.3s
# 91:	learn: -0.5381973	total: 8.93s	remaining: 20.2s
# 92:	learn: -0.5349661	total: 8.99s	remaining: 20s
# 93:	learn: -0.5313568	total: 9.06s	remaining: 19.9s
# 94:	learn: -0.5275061	total: 9.14s	remaining: 19.7s
# 95:	learn: -0.5240487	total: 9.21s	remaining: 19.6s
# 96:	learn: -0.5200314	total: 9.29s	remaining: 19.4s
# 97:	learn: -0.5174033	total: 9.37s	remaining: 19.3s
# 98:	learn: -0.5141316	total: 9.43s	remaining: 19.2s
# 99:	learn: -0.5112125	total: 9.51s	remaining: 19s
# 100:	learn: -0.5072344	total: 9.58s	remaining: 18.9s
# 101:	learn: -0.5035766	total: 9.66s	remaining: 18.8s
# 102:	learn: -0.5011110	total: 9.86s	remaining: 18.9s
# 103:	learn: -0.4982390	total: 10.1s	remaining: 19s
# 104:	learn: -0.4953067	total: 10.3s	remaining: 19.1s
# 105:	learn: -0.4929489	total: 10.5s	remaining: 19.3s
# 106:	learn: -0.4906389	total: 10.7s	remaining: 19.3s
# 107:	learn: -0.4875100	total: 10.8s	remaining: 19.2s
# 108:	learn: -0.4849565	total: 10.9s	remaining: 19s
# 109:	learn: -0.4825757	total: 10.9s	remaining: 18.8s
# 110:	learn: -0.4813140	total: 11s	remaining: 18.7s
# 111:	learn: -0.4784587	total: 11s	remaining: 18.5s
# 112:	learn: -0.4758540	total: 11.1s	remaining: 18.4s
# 113:	learn: -0.4735677	total: 11.1s	remaining: 18.2s
# 114:	learn: -0.4710926	total: 11.2s	remaining: 18s
# 115:	learn: -0.4688927	total: 11.3s	remaining: 17.9s
# 116:	learn: -0.4672199	total: 11.3s	remaining: 17.7s
# 117:	learn: -0.4650627	total: 11.4s	remaining: 17.6s
# 118:	learn: -0.4633839	total: 11.4s	remaining: 17.4s
# 119:	learn: -0.4610439	total: 11.5s	remaining: 17.3s
# 120:	learn: -0.4591400	total: 11.6s	remaining: 17.1s
# 121:	learn: -0.4573462	total: 11.6s	remaining: 16.9s
# 122:	learn: -0.4551801	total: 11.8s	remaining: 17.1s
# 123:	learn: -0.4530991	total: 12.1s	remaining: 17.1s
# 124:	learn: -0.4515631	total: 12.4s	remaining: 17.3s
# 125:	learn: -0.4499529	total: 12.6s	remaining: 17.4s
# 126:	learn: -0.4476883	total: 12.7s	remaining: 17.3s
# 127:	learn: -0.4453167	total: 12.7s	remaining: 17.1s
# 128:	learn: -0.4441563	total: 12.8s	remaining: 17s
# 129:	learn: -0.4422288	total: 12.9s	remaining: 16.8s
# 130:	learn: -0.4402555	total: 12.9s	remaining: 16.7s
# 131:	learn: -0.4388827	total: 13s	remaining: 16.5s
# 132:	learn: -0.4366163	total: 13s	remaining: 16.4s
# 133:	learn: -0.4345720	total: 13.1s	remaining: 16.2s
# 134:	learn: -0.4332972	total: 13.2s	remaining: 16.1s
# 135:	learn: -0.4317199	total: 13.2s	remaining: 15.9s
# 136:	learn: -0.4302771	total: 13.3s	remaining: 15.8s
# 137:	learn: -0.4283594	total: 13.3s	remaining: 15.7s
# 138:	learn: -0.4268156	total: 13.4s	remaining: 15.5s
# 139:	learn: -0.4251186	total: 13.5s	remaining: 15.4s
# 140:	learn: -0.4238823	total: 13.5s	remaining: 15.3s
# 141:	learn: -0.4226014	total: 13.7s	remaining: 15.2s
# 142:	learn: -0.4214630	total: 14s	remaining: 15.3s
# 143:	learn: -0.4195679	total: 14.2s	remaining: 15.4s
# 144:	learn: -0.4185161	total: 14.5s	remaining: 15.5s
# 145:	learn: -0.4166338	total: 14.6s	remaining: 15.4s
# 146:	learn: -0.4154909	total: 14.7s	remaining: 15.3s
# 147:	learn: -0.4145206	total: 14.7s	remaining: 15.1s
# 148:	learn: -0.4130640	total: 14.8s	remaining: 15s
# 149:	learn: -0.4116968	total: 14.8s	remaining: 14.8s
# 150:	learn: -0.4104446	total: 14.9s	remaining: 14.7s
# 151:	learn: -0.4091952	total: 15s	remaining: 14.6s
# 152:	learn: -0.4077444	total: 15.1s	remaining: 14.5s
# 153:	learn: -0.4064164	total: 15.1s	remaining: 14.4s
# 154:	learn: -0.4056470	total: 15.2s	remaining: 14.2s
# 155:	learn: -0.4043621	total: 15.3s	remaining: 14.1s
# 156:	learn: -0.4034477	total: 15.3s	remaining: 14s
# 157:	learn: -0.4025300	total: 15.4s	remaining: 13.8s
# 158:	learn: -0.4011349	total: 15.5s	remaining: 13.7s
# 159:	learn: -0.4002345	total: 15.6s	remaining: 13.7s
# 160:	learn: -0.3992833	total: 15.9s	remaining: 13.7s
# 161:	learn: -0.3982952	total: 16s	remaining: 13.7s
# 162:	learn: -0.3974041	total: 16.3s	remaining: 13.7s
# 163:	learn: -0.3959731	total: 16.5s	remaining: 13.7s
# 164:	learn: -0.3952075	total: 16.6s	remaining: 13.6s
# 165:	learn: -0.3942399	total: 16.7s	remaining: 13.5s
# 166:	learn: -0.3933321	total: 16.8s	remaining: 13.3s
# 167:	learn: -0.3918039	total: 16.8s	remaining: 13.2s
# 168:	learn: -0.3906413	total: 16.9s	remaining: 13.1s
# 169:	learn: -0.3893478	total: 17s	remaining: 13s
# 170:	learn: -0.3880017	total: 17s	remaining: 12.8s
# 171:	learn: -0.3868276	total: 17.1s	remaining: 12.7s
# 172:	learn: -0.3852582	total: 17.1s	remaining: 12.6s
# 173:	learn: -0.3844134	total: 17.2s	remaining: 12.5s
# 174:	learn: -0.3831889	total: 17.3s	remaining: 12.4s
# 175:	learn: -0.3819702	total: 17.4s	remaining: 12.2s
# 176:	learn: -0.3808575	total: 17.5s	remaining: 12.2s
# 177:	learn: -0.3797277	total: 17.7s	remaining: 12.1s
# 178:	learn: -0.3786379	total: 18s	remaining: 12.1s
# 179:	learn: -0.3780386	total: 18.2s	remaining: 12.1s
# 180:	learn: -0.3769457	total: 18.4s	remaining: 12.1s
# 181:	learn: -0.3756391	total: 18.5s	remaining: 12s
# 182:	learn: -0.3745824	total: 18.5s	remaining: 11.8s
# 183:	learn: -0.3738427	total: 18.6s	remaining: 11.7s
# 184:	learn: -0.3728439	total: 18.7s	remaining: 11.6s
# 185:	learn: -0.3718807	total: 18.7s	remaining: 11.5s
# 186:	learn: -0.3710200	total: 18.8s	remaining: 11.4s
# 187:	learn: -0.3702445	total: 18.9s	remaining: 11.2s
# 188:	learn: -0.3696498	total: 18.9s	remaining: 11.1s
# 189:	learn: -0.3688349	total: 19s	remaining: 11s
# 190:	learn: -0.3682059	total: 19.1s	remaining: 10.9s
# 191:	learn: -0.3672178	total: 19.1s	remaining: 10.8s
# 192:	learn: -0.3663605	total: 19.2s	remaining: 10.6s
# 193:	learn: -0.3656348	total: 19.2s	remaining: 10.5s
# 194:	learn: -0.3643773	total: 19.3s	remaining: 10.4s
# 195:	learn: -0.3634957	total: 19.5s	remaining: 10.3s
# 196:	learn: -0.3625718	total: 19.7s	remaining: 10.3s
# 197:	learn: -0.3617861	total: 19.9s	remaining: 10.2s
# 198:	learn: -0.3607749	total: 20.1s	remaining: 10.2s
# 199:	learn: -0.3598967	total: 20.3s	remaining: 10.1s
# 200:	learn: -0.3582663	total: 20.4s	remaining: 10s
# 201:	learn: -0.3576701	total: 20.4s	remaining: 9.9s
# 202:	learn: -0.3565771	total: 20.5s	remaining: 9.78s
# 203:	learn: -0.3554916	total: 20.5s	remaining: 9.66s
# 204:	learn: -0.3547065	total: 20.6s	remaining: 9.56s
# 205:	learn: -0.3541354	total: 20.7s	remaining: 9.46s
# 206:	learn: -0.3533888	total: 20.8s	remaining: 9.34s
# 207:	learn: -0.3528175	total: 20.9s	remaining: 9.22s
# 208:	learn: -0.3518152	total: 20.9s	remaining: 9.11s
# 209:	learn: -0.3508725	total: 21s	remaining: 9.01s
# 210:	learn: -0.3501584	total: 21.1s	remaining: 8.9s
# 211:	learn: -0.3492280	total: 21.2s	remaining: 8.79s
# 212:	learn: -0.3485890	total: 21.3s	remaining: 8.69s
# 213:	learn: -0.3472016	total: 21.5s	remaining: 8.64s
# 214:	learn: -0.3463298	total: 21.7s	remaining: 8.59s
# 215:	learn: -0.3456959	total: 21.9s	remaining: 8.54s
# 216:	learn: -0.3447416	total: 22.2s	remaining: 8.5s
# 217:	learn: -0.3438235	total: 22.3s	remaining: 8.39s
# 218:	learn: -0.3432713	total: 22.4s	remaining: 8.28s
# 219:	learn: -0.3426278	total: 22.4s	remaining: 8.16s
# 220:	learn: -0.3418544	total: 22.5s	remaining: 8.04s
# 221:	learn: -0.3409504	total: 22.6s	remaining: 7.93s
# 222:	learn: -0.3401244	total: 22.6s	remaining: 7.81s
# 223:	learn: -0.3391519	total: 22.7s	remaining: 7.7s
# 224:	learn: -0.3385670	total: 22.7s	remaining: 7.58s
# 225:	learn: -0.3376862	total: 22.8s	remaining: 7.47s
# 226:	learn: -0.3369827	total: 22.9s	remaining: 7.35s
# 227:	learn: -0.3361571	total: 22.9s	remaining: 7.24s
# 228:	learn: -0.3354258	total: 23s	remaining: 7.13s
# 229:	learn: -0.3351625	total: 23.1s	remaining: 7.02s
# 230:	learn: -0.3346343	total: 23.1s	remaining: 6.91s
# 231:	learn: -0.3340469	total: 23.3s	remaining: 6.82s
# 232:	learn: -0.3328459	total: 23.4s	remaining: 6.74s
# 233:	learn: -0.3321751	total: 23.7s	remaining: 6.67s
# 234:	learn: -0.3311533	total: 23.8s	remaining: 6.59s
# 235:	learn: -0.3303889	total: 24.1s	remaining: 6.53s
# 236:	learn: -0.3294795	total: 24.2s	remaining: 6.42s
# 237:	learn: -0.3287793	total: 24.2s	remaining: 6.31s
# 238:	learn: -0.3279287	total: 24.3s	remaining: 6.2s
# 239:	learn: -0.3273955	total: 24.3s	remaining: 6.08s
# 240:	learn: -0.3268820	total: 24.4s	remaining: 5.97s
# 241:	learn: -0.3260956	total: 24.5s	remaining: 5.86s
# 242:	learn: -0.3254373	total: 24.5s	remaining: 5.75s
# 243:	learn: -0.3250267	total: 24.6s	remaining: 5.64s
# 244:	learn: -0.3243844	total: 24.6s	remaining: 5.53s
# 245:	learn: -0.3235590	total: 24.7s	remaining: 5.42s
# 246:	learn: -0.3226892	total: 24.7s	remaining: 5.31s
# 247:	learn: -0.3221749	total: 24.8s	remaining: 5.2s
# 248:	learn: -0.3214273	total: 24.9s	remaining: 5.09s
# 249:	learn: -0.3205242	total: 24.9s	remaining: 4.98s
# 250:	learn: -0.3199609	total: 25s	remaining: 4.88s
# 251:	learn: -0.3195012	total: 25.2s	remaining: 4.79s
# 252:	learn: -0.3187666	total: 25.4s	remaining: 4.71s
# 253:	learn: -0.3182517	total: 25.6s	remaining: 4.63s
# 254:	learn: -0.3174332	total: 25.8s	remaining: 4.55s
# 255:	learn: -0.3165420	total: 26s	remaining: 4.47s
# 256:	learn: -0.3160654	total: 26.1s	remaining: 4.36s
# 257:	learn: -0.3155032	total: 26.1s	remaining: 4.25s
# 258:	learn: -0.3148496	total: 26.2s	remaining: 4.14s
# 259:	learn: -0.3145155	total: 26.3s	remaining: 4.04s
# 260:	learn: -0.3139240	total: 26.3s	remaining: 3.93s
# 261:	learn: -0.3134119	total: 26.4s	remaining: 3.82s
# 262:	learn: -0.3127942	total: 26.4s	remaining: 3.72s
# 263:	learn: -0.3123199	total: 26.5s	remaining: 3.61s
# 264:	learn: -0.3117617	total: 26.5s	remaining: 3.51s
# 265:	learn: -0.3111892	total: 26.6s	remaining: 3.4s
# 266:	learn: -0.3106480	total: 26.7s	remaining: 3.3s
# 267:	learn: -0.3098939	total: 26.7s	remaining: 3.19s
# 268:	learn: -0.3090014	total: 26.8s	remaining: 3.09s
# 269:	learn: -0.3079598	total: 26.9s	remaining: 2.98s
# 270:	learn: -0.3074836	total: 26.9s	remaining: 2.88s
# 271:	learn: -0.3067197	total: 27.1s	remaining: 2.79s
# 272:	learn: -0.3060759	total: 27.3s	remaining: 2.7s
# 273:	learn: -0.3054840	total: 27.5s	remaining: 2.61s
# 274:	learn: -0.3050389	total: 27.8s	remaining: 2.53s
# 275:	learn: -0.3042445	total: 27.9s	remaining: 2.43s
# 276:	learn: -0.3037784	total: 28s	remaining: 2.33s
# 277:	learn: -0.3032943	total: 28.1s	remaining: 2.22s
# 278:	learn: -0.3028646	total: 28.1s	remaining: 2.12s
# 279:	learn: -0.3023282	total: 28.2s	remaining: 2.01s
# 280:	learn: -0.3016874	total: 28.3s	remaining: 1.91s
# 281:	learn: -0.3008158	total: 28.4s	remaining: 1.81s
# 282:	learn: -0.3002125	total: 28.4s	remaining: 1.71s
# 283:	learn: -0.2997953	total: 28.5s	remaining: 1.6s
# 284:	learn: -0.2992251	total: 28.6s	remaining: 1.5s
# 285:	learn: -0.2986269	total: 28.6s	remaining: 1.4s
# 286:	learn: -0.2981643	total: 28.7s	remaining: 1.3s
# 287:	learn: -0.2977876	total: 28.8s	remaining: 1.2s
# 288:	learn: -0.2970415	total: 28.9s	remaining: 1.1s
# 289:	learn: -0.2964136	total: 29.2s	remaining: 1.01s
# 290:	learn: -0.2958215	total: 29.4s	remaining: 909ms
# 291:	learn: -0.2952251	total: 29.7s	remaining: 813ms
# 292:	learn: -0.2947918	total: 29.8s	remaining: 712ms
# 293:	learn: -0.2940281	total: 29.9s	remaining: 610ms
# 294:	learn: -0.2933597	total: 30s	remaining: 508ms
# 295:	learn: -0.2928677	total: 30s	remaining: 406ms
# 296:	learn: -0.2924260	total: 30.1s	remaining: 304ms
# 297:	learn: -0.2920077	total: 30.2s	remaining: 202ms
# 298:	learn: -0.2914025	total: 30.2s	remaining: 101ms
# 299:	learn: -0.2910622	total: 30.3s	remaining: 0us

# %%
from itertools import accumulate
from collections import Counter

vect, reg = model

test_vect_data = enrich(dense_vectors(vect.transform(test_data)), test_data)
predicted = reg.predict(test_vect_data)

volumes_stats = Counter(volumes)
p = list(accumulate(count/len(volumes) for _, count in volumes_stats.items()))
top_volumes = np.sort([volume for i, volume in enumerate(volumes_stats)
                if p[i] <= 0.8])

def closest(volumes, v):
    closest = np.abs(volumes - v).argmin()
    return volumes[closest]

table = {
    'Input': test_data,
    'Predicted volume': np.array([ closest(top_volumes, v) for v in predicted]),
    'Valid volume': test_volumes,
}

result = pd.DataFrame(table, columns = ['Input', 'Predicted volume', 'Valid volume'])
result.head(20)
# Out:
#                                                 Input  Predicted volume  \
# 0             Пиво СТЕПАН РАЗИН ПЕТР.св.4,7% ПЭТ 1.4л              1.50
# 1             ZLATY BAZANT - светлое 4.1% - 0.5л ж.б.              0.50
# 2             Пиво MILLER MIDNIGHT тем.4,8% ст/б 0.5л              0.50
# 3               КЛИНСКОЕ - светлое 4.5% - 0.5л стекло              0.50
# 4            ПивоANDECH.ВАЙСБ.ХЕФЕТР.св.5,5%ст/б 0.5л              0.50
# 5               ЖИГУЛЕВСКОЕ - светлое 4.2% - 1.5л пэт              1.50
# 6                     Пиво ЯРПИВО КРЕПК.св. 7,2% 0.5л              0.50
# 7                БАЛТИКА - светлое 5.4% - 0.5л стекло              0.50
# 8   SIBIRSKAYA KORONA(AB INBEV) KLASSICHESKOE 0.5L...              0.50
# 9   OKHOTA(HEINEKEN BEL) KREPKOE EKSPORTNOE 1.4L P...              1.50
# 10            CLAUSTHALER - светлое 0% - 0.33л стекло              0.33
# 11                 НЕВСКОЕ - светлое 5.7% - 0.5л ж.б.              0.50
# 12                  TUBORG - светлое 4.6% - 0.5л ж.б.              0.50
# 13                 Пиво KRUSOVICE СВЕТЛЕ св.4,2% 0.5л              0.50
# 14           Нап.С&Р.ГАР.ХАРД БРУС.осн.пив.4,6% 0.44л              0.44
# 15                     CORONA EXTRA 6X0.355L J BO L F              0.50
# 16                 Пиво КЕР САРИ ТЕМНОЕ 4,3% ж/б 0.5л              0.50
# 17  BOLSHAYA KRUZHKA(BALTIKA) YANTARNOE 1.425L P B...              1.50
# 18                 Пиво СТАР.МЕЛЬНИК св.4,7% ж/б 0.5л              0.50
# 19  ZHIGULYOVSK.(AB INBEV) ORIGINALNOE 0.47L J BO L X              2.50
#
#     Valid volume
# 0          1.400
# 1          0.500
# 2          0.500
# 3          0.500
# 4          0.500
# 5          1.500
# 6          0.500
# 7          0.500
# 8          0.500
# 9          1.400
# 10         0.330
# 11         0.500
# 12         0.500
# 13         0.500
# 14         0.440
# 15         0.355
# 16         0.500
# 17         1.425
# 18         0.500
# 19         4.700

# %%
len(result[result['Predicted volume']!=result['Valid volume']])/len(result)
# Out:
# 0.23048907388137357

# %%
from joblib as load, dump

name = f"beer_volume"

vect, reg = model
dump(vect, f"{name}_vect.job")
reg.save
